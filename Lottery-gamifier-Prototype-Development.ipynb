# %% [markdown]
# # Lottery gamifier

# %% [markdown]
# ### Methodology
# * Choose random retailers meeting certain criteria weighted based on the purchasing ability of retailers (previous day order is considered as purchasing ability)
# * Choose the number of random retailers based on the weightage of number of retailers under each AM & retail group
# * Choose the number of retailers (one fourth) of total retailers in a day

# %% [markdown]
# ### Steps

# %% [markdown]
# 1. Import packages
# 2. Import data
# 3. Remove null
# 4. Occurence of Retailer
# 5. Weightage for AM & Retail group
# 6. Split data based on AM's & Retail group
# 7. Function to generate random Rtr's by weight of AM Retail group
# 8. Move last day from Results to History
# 9. Read & join csv in History
# 10. Main logic with Voila for Web app

# %% [markdown]
# ### Import packages

# %%
from ckpackages import azsql #customer package
import numpy as np
import pandas as pd
import random
import datetime as dt

# %% [markdown]
# ### Import data

# %%
Query = 'select * from v_PC_MeeraRetailerCampaign' 
#Transactions for Meera Powder
data = azsql.callstatement(Query)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1978 entries, 0 to 1977
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RtrCode         1978 non-null   object
#  1   RtrName         1978 non-null   object
#  2   RtrGroupCde     1962 non-null   object
#  3   DistName        1978 non-null   object
#  4   BillNo          1978 non-null   object
#  5   InvDate         1978 non-null   datetime64[ns]
#  6   Brand           1978 non-null   object
#  7   PrdName         1978 non-null   object
#  8   StateName       0 non-null      object
#  9   ZM              1978 non-null   object
#  10  AMName          1978 non-null   object
#  11  TSOName         1978 non-null   object
#  12  SMSysName       1978 non-null   object
#  13  TotalQty        1978 non-null   float64
#  14  PolypouchCount  1978 non-null   float64
#  15  FinYr           1978 non-null   object
#  16  JC              1978 non-null   object
#  17  JCWk            1978 non-null   object
# dtypes: datetime64[ns](1), float64(2), object(15)
# memory usage: 278.3+ KB

# %%
data.head()
# Out:
#                                      RtrCode                   RtrName  \
# 0                        S100000031550047076  BHAVANI PROVISION STORE
# 1  GT0100020075280002007528-SLM0031584524384      Mathura super market
# 2                  TNSSR009-SLM0011551259675             K.N. Brothers
# 3                        S100000221550322447            Lakshmi STORE
# 4                        S100000021551525328         VIJALAKSHMI STORE
#
#                                        RtrGroupCde             DistName  \
# 0                         PC-KIRANA/GENERAL STORES           PONNI & CO
# 1  PC-Super Market (MT in GT & Departmental Store)           PONNI & CO
# 2                                     PC-WHOLESALE           PONNI & CO
# 3                         PC-KIRANA/GENERAL STORES  HARISH KANNA AGENCY
# 4                         PC-KIRANA/GENERAL STORES           PONNI & CO
#
#          BillNo    InvDate                 Brand  \
# 0  CKBIL2008550 2020-10-26  Meera Powder & Paste
# 1  CKBIL2008151 2020-10-21  Meera Powder & Paste
# 2  CKBIL2008261 2020-10-22  Meera Powder & Paste
# 3  CKBIL2012296 2020-10-24         Meera Shampoo
# 4  CKBIL2008332 2020-10-23  Meera Powder & Paste
#
#                                     PrdName StateName         ZM    AMName  \
# 0  MEERA HRB PWD 5.6 GM 1350 PCS DIWALI OFF      None  C PERUMAL  BALAJI S
# 1  MEERA HRB PWD 5.6 GM 1350 PCS DIWALI OFF      None  C PERUMAL  BALAJI S
# 2  MEERA HRB PWD 5.6 GM 1350 PCS DIWALI OFF      None  C PERUMAL  BALAJI S
# 3  MEERA HRB PWD 5.6 GM 1350 PCS DIWALI OFF      None  C PERUMAL  BALAJI S
# 4  MEERA HRB PWD 5.6 GM 1350 PCS DIWALI OFF      None  C PERUMAL  BALAJI S
#
#          TSOName  SMSysName  TotalQty  PolypouchCount    FinYr    JC  JCWk
# 0  ASHOK KUMAR R  GOWTHAM B     150.0             1.0  2020-21  JC08  WK02
# 1  ASHOK KUMAR R  GOWTHAM B     450.0             3.0  2020-21  JC08  WK01
# 2  ASHOK KUMAR R  GOWTHAM B    1350.0             9.0  2020-21  JC08  WK02
# 3  ASHOK KUMAR R    KUMAR K     150.0             1.0  2020-21  JC08  WK02
# 4  ASHOK KUMAR R  GOWTHAM B     150.0             1.0  2020-21  JC08  WK02

# %%
data['weekday'] = data['InvDate'].dt.dayofweek

# %%
currentWeekDay = dt.datetime.now().weekday()

# %%
# Data only for Latest date
# On monday, get Sat & Sun data, for other days, get previous day data
if currentWeekDay==0:
    cutoff_date = data['InvDate'].max() - pd.Timedelta(days=1)
    max_date = data['InvDate'].max()
    
    data = data[(data['InvDate'] >= cutoff_date)]
    data = data[(data['InvDate'] <= max_date)]
else:
    data = data[data['InvDate'] == data['InvDate'].max()]

# %%
data.head(2)
# Out:
#                RtrCode                   RtrName               RtrGroupCde  \
# 0  S100000031550047076  BHAVANI PROVISION STORE   PC-KIRANA/GENERAL STORES
# 6  S100000031551860860        S GANAPATHY STORE   PC-KIRANA/GENERAL STORES
#
#      DistName        BillNo    InvDate                 Brand  \
# 0  PONNI & CO  CKBIL2008550 2020-10-26  Meera Powder & Paste
# 6  PONNI & CO  CKBIL2008544 2020-10-26  Meera Powder & Paste
#
#                                     PrdName StateName         ZM    AMName  \
# 0  MEERA HRB PWD 5.6 GM 1350 PCS DIWALI OFF      None  C PERUMAL  BALAJI S
# 6  MEERA HRB PWD 5.6 GM 1350 PCS DIWALI OFF      None  C PERUMAL  BALAJI S
#
#          TSOName  SMSysName  TotalQty  PolypouchCount    FinYr    JC  JCWk  \
# 0  ASHOK KUMAR R  GOWTHAM B     150.0             1.0  2020-21  JC08  WK02
# 6  ASHOK KUMAR R  GOWTHAM B     150.0             1.0  2020-21  JC08  WK02
#
#    weekday
# 0        0
# 6        0

# %%
data.InvDate.unique()
# Out:
# array(['2020-10-26T00:00:00.000000000'], dtype='datetime64[ns]')

# %% [markdown]
# ### Remove null

# %%
# Retailers without AM
print(data['AMName'].isnull().sum())
data[data['AMName'].isnull()]
# Out:
# 0
# Empty DataFrame
# Columns: [RtrCode, RtrName, RtrGroupCde, DistName, BillNo, InvDate, Brand, PrdName, StateName, ZM, AMName, TSOName, SMSysName, TotalQty, PolypouchCount, FinYr, JC, JCWk, weekday]
# Index: []

# %%
# Consider Data with AMName ( remove nulls)
data = data[data['AMName'].notnull()]

# %%
data['RtrGroupCde1'] = data['RtrGroupCde'].apply(lambda x: 'PC-WHOLESALE' if x=='PC-WHOLESALE' else 'PC-RETAIL')

# %%
# Filter wholesale retailers
#data = data[data['RtrGroupCde1'] == 'PC-WHOLESALE']

# %% [markdown]
# ### Occurence of Retailer

# %%
# List of retailer
rt = data['RtrCode'].tolist()
rt.sort()
rtr = pd.Series(rt).value_counts()
rtr_list = pd.DataFrame(rtr,columns = ['retailer'] )
rtr_list['retailer']
# Out:
# GT0100020001360002000136-SLM0011579689437    2
# S100000451552283974                          2
# TNPAA005-SLM0031552456412                    2
# GT0100020001140002000114-SLM0021561025513    2
# TNSPA013-SLM0011552293788                    2
#                                             ..
# GT0100020001430002000143-SLM0011561364574    1
# S100000381550912490                          1
# TNVIA013-SLM0011552115388                    1
# GT0100020000770002000077-SLM0011556092297    1
# GT0100020001360002000136-SLM0011557303441    1
# Name: retailer, Length: 89, dtype: int64

# %%
# Maximum occurence of retailer
rtr_list['retailer'].max()
# Out:
# 5

# %%
rtr_master = data[['RtrCode','RtrName','SMSysName','DistName','RtrGroupCde1','RtrGroupCde','InvDate','PolypouchCount']].drop_duplicates()

# %%
rtr_master['PolypouchCount'] = rtr_master['PolypouchCount'].astype(int)

# %%
# Choose number of retailers to choose
pick = 75

# %% [markdown]
# ### Weightage for AM

# %%
# Percentage of Retailers across AM-Wise
#TotalRtrCount = data['RtrCode'].count()
#AM_RTR_WGT = data.groupby('AMName')['RtrCode'].count().reset_index()
#AM_RTR_WGT['WGT%'] = np.ceil((AM_RTR_WGT['RtrCode']/TotalRtrCount) * pick)

#AM_RTR_WGT

# %%
# Percentage of Retailers across AM-Wise & Retailer group wise
TotalRtrCount = data['RtrCode'].count()
AM_RTR_WGT = data.groupby(['AMName','RtrGroupCde1'])['RtrCode'].count().reset_index()
AM_RTR_WGT['WGT%'] = np.ceil((AM_RTR_WGT['RtrCode']/TotalRtrCount) * pick)

AM_RTR_WGT
# Out:
#          AMName  RtrGroupCde1  RtrCode  WGT%
# 0      BALAJI S  PC-WHOLESALE       23  18.0
# 1  SAFFIULLAH R  PC-WHOLESALE       38  30.0
# 2  SYED IBRAHIM  PC-WHOLESALE       30  24.0
# 3    V BHARATHI  PC-WHOLESALE        5   4.0

# %%
TotalRtrCount
# Out:
# 96

# %% [markdown]
# ### Split dataframe on AM's

# %%
# Select required rows
data1 = data[['ZM','AMName','SMSysName','RtrGroupCde1','RtrCode','RtrName','TotalQty','PolypouchCount']]

# %%
data2 = [rows for _, rows in data1.groupby(['AMName','RtrGroupCde1'])]

# %%
data2[0]
data2[1]
data2[2]
data2[3]
# Out:
#              ZM        AMName     SMSysName  RtrGroupCde1  \
# 840   C PERUMAL  SAFFIULLAH R       BHARATH  PC-WHOLESALE
# 890   C PERUMAL  SAFFIULLAH R  MANIKANDAN S  PC-WHOLESALE
# 965   C PERUMAL  SAFFIULLAH R      JEEVAGAN  PC-WHOLESALE
# 968   C PERUMAL  SAFFIULLAH R       SIVARAM  PC-WHOLESALE
# 977   C PERUMAL  SAFFIULLAH R   SUBA SANJAY  PC-WHOLESALE
# 1037  C PERUMAL  SAFFIULLAH R  ASHOK VILSAN  PC-WHOLESALE
# 1049  C PERUMAL  SAFFIULLAH R     KUPPUSAMY  PC-WHOLESALE
#
#                                         RtrCode  \
# 840                         S100000681551162809
# 890                         S100000601551766148
# 965                         S100000661550907010
# 968   GT0100020001200002000120-SLM0021564152210
# 977                         S100000551557830324
# 1037                  TNRST003-SLM0011552631513
# 1049  GT0100020001120002000112-SLM0021557483209
#
#                                RtrName  TotalQty  PolypouchCount
# 840                       RADHA STORE      375.0             2.5
# 890                        MUTHU STORE    2700.0            18.0
# 965                      SAROJA STORES   13500.0            90.0
# 968                SAKTHIMURUGAN STORE   13500.0            90.0
# 977            jai rajputana marketing    1350.0             9.0
# 1037  EASWARAN SETTIYAR CENTRAL MARKET     150.0             1.0
# 1049                    RAHAMATH STORE    1350.0             9.0

# %% [markdown]
# ## Function to generate random Rtr's

# %% [markdown]
# ### Case: With repetitions (allowing 1st two instances of duplicates)

# %%
def randomRtrAmWise(i):
    # Retailer name
    a = data2[i]['RtrCode'].tolist()

    # Polypouch count as weight
    ppc = data2[i]['PolypouchCount'].tolist() 

    c=int(AM_RTR_WGT['WGT%'][i])
#    random.shuffle(a)
    l = random.choices(a, weights=ppc, k=c)
    l.sort()
    df_R = pd.DataFrame(l,columns = ['RtrCode'])
    df_R['AMName'] = AM_RTR_WGT['AMName'][i]
    return df_R
    
def randompick(AM_RTR_WGT):
    df_RtrRP = pd.DataFrame()
    for j in range(len( AM_RTR_WGT.index.tolist())):
        df = randomRtrAmWise(j)
        df_RtrRP = df_RtrRP.append(df)
    return df_RtrRP

def randompickAM():
    result = randompick(AM_RTR_WGT)
    result = result.merge(rtr_master,on='RtrCode')
    result = result.groupby('RtrCode').head(2).reset_index(drop=True) # Keep 1st two instances of duplicates
    index = result.index
    number_of_rows = len(index)
    print('Count of picked retailers: ',number_of_rows)
    #result.to_csv('results').csv',index=False)
    return result

# %%
randompickAM()
# Out:
# Count of picked retailers:  53
#                                       RtrCode        AMName  \
# 0   GT0100020000770002000077-SLM0011556090444      BALAJI S
# 1   GT0100020000770002000077-SLM0011556093164      BALAJI S
# 2                         S100000011550661438      BALAJI S
# 3                         S100000161550640721      BALAJI S
# 4                         S100000161563351070      BALAJI S
# 5                         S100000161563351070      BALAJI S
# 6                         S100000401550574992      BALAJI S
# 7                         S100000441550736349      BALAJI S
# 8                         S100000451551082187      BALAJI S
# 9                         S100000451551083515      BALAJI S
# 10                        S100000451552283974      BALAJI S
# 11                        S100000451552283974      BALAJI S
# 12                        S100000501551084098      BALAJI S
# 13  GT0100020001140002000114-SLM0021561025513  SAFFIULLAH R
# 14  GT0100020001140002000114-SLM0021561025513  SAFFIULLAH R
# 15  GT0100020001140002000114-SLM0021561722215  SAFFIULLAH R
# 16  GT0100020001140002000114-SLM0021561722215  SAFFIULLAH R
# 17  GT0100020001140002000114-SLM0021571114862  SAFFIULLAH R
# 18  GT0100020001140002000114-SLM0021571114862  SAFFIULLAH R
# 19  GT0100020001290002000129-SLM0011556774247  SAFFIULLAH R
# 20  GT0100020001360002000136-SLM0011579689437  SAFFIULLAH R
# 21  GT0100020001360002000136-SLM0011579689437  SAFFIULLAH R
# 22                        S100000701553153015  SAFFIULLAH R
# 23                        S100000701553153015  SAFFIULLAH R
# 24                  TNSPA013-SLM0011552293788  SAFFIULLAH R
# 25                  TNSPA013-SLM0011552293788  SAFFIULLAH R
# 26                  TNSPA013-SLM0011552296657  SAFFIULLAH R
# 27                  TNSPA013-SLM0011552296657  SAFFIULLAH R
# 28                  TNSPA013-SLM0011552297642  SAFFIULLAH R
# 29                  TNSPA013-SLM0011552302643  SAFFIULLAH R
# 30                  TNSPA013-SLM0011552302643  SAFFIULLAH R
# 31                  TNSPA022-SLM0011552636770  SAFFIULLAH R
# 32                  TNSPA022-SLM0011552636770  SAFFIULLAH R
# 33                  TNVIA013-SLM0011553507531  SAFFIULLAH R
# 34                  TNVIA013-SLM0011553507531  SAFFIULLAH R
# 35  GT0100020001400002000140-SLM0011582704715  SYED IBRAHIM
# 36  GT0100020001430002000143-SLM0011561364574  SYED IBRAHIM
# 37  GT0100020001430002000143-SLM0011561364574  SYED IBRAHIM
# 38  GT0100020001540002000154-SLM0011556710664  SYED IBRAHIM
# 39  GT0100020001600002000160-SLM0011556279048  SYED IBRAHIM
# 40  GT0100020001600002000160-SLM0011556279048  SYED IBRAHIM
# 41  GT0100020001780002000178-SLM0071555311540  SYED IBRAHIM
# 42                        S100000951550918786  SYED IBRAHIM
# 43                        S100000951550918786  SYED IBRAHIM
# 44                  TNGMM001-SLM0011552913560  SYED IBRAHIM
# 45                  TNLUM001-SLM0021552472586  SYED IBRAHIM
# 46                  TNLUM001-SLM0021553080059  SYED IBRAHIM
# 47                  TNSVA046-SLM0011553677696  SYED IBRAHIM
# 48                  TNSVA046-SLM0011553677696  SYED IBRAHIM
# 49  GT0100020000860002000086-SLM0011557988279    V BHARATHI
# 50  GT0100020000860002000086-SLM0011557988279    V BHARATHI
# 51  GT0100020000860002000086-SLM0011557989802    V BHARATHI
# 52                        S100000321603266161    V BHARATHI
#
#                         RtrName         SMSysName  \
# 0   PARSV PADMAVATI ENTERPRISES              LOGU
# 1            V. N. ARUMUGAM &CO              LOGU
# 2                 SANJANA STORE    THIRUMOORTHI V
# 3            SRI KAMATCHI STORE       TAMILSELVAN
# 4         SRI THIRUPTHI TRADERS       TAMILSELVAN
# 5         SRI THIRUPTHI TRADERS       TAMILSELVAN
# 6                 Perumal store   KRISHNA MOORTHY
# 7                NANDHINI STORE   JAYENDRAKUMAR M
# 8             Sri tharani store      JEEVAJOTHI C
# 9       Sri jai narayana stores      JEEVAJOTHI C
# 10       Sri duraiappa agencies      JEEVAJOTHI C
# 11       Sri duraiappa agencies      JEEVAJOTHI C
# 12                   JOHN STORE       PARTHIBAN S
# 13                  dheen store             SEKAR
# 14                  dheen store             SEKAR
# 15               Bagiya store 3             SEKAR
# 16               Bagiya store 3             SEKAR
# 17         Thangapandiyan store             SEKAR
# 18         Thangapandiyan store             SEKAR
# 19             valarmathi store         VADIVEL P
# 20                LUHA TRADERS     SUBRAMANIYAM M
# 21                LUHA TRADERS     SUBRAMANIYAM M
# 22            SRI KRISHNA STORE      MANIKANDAN S
# 23            SRI KRISHNA STORE      MANIKANDAN S
# 24        GOBU GENDERAL STORES    THIRUVENKATAM S
# 25        GOBU GENDERAL STORES    THIRUVENKATAM S
# 26           MATHAJI MARKETING    THIRUVENKATAM S
# 27           MATHAJI MARKETING    THIRUVENKATAM S
# 28      RAMESH TRADING COMPANY    THIRUVENKATAM S
# 29          SHIV SAKTHI STORES    THIRUVENKATAM S
# 30          SHIV SAKTHI STORES    THIRUVENKATAM S
# 31                KRISHNA STORE          SURESH A
# 32                KRISHNA STORE          SURESH A
# 33                SANTHILAL&CO,    SUBRAMANIYAM M
# 34                SANTHILAL&CO,    SUBRAMANIYAM M
# 35                    V.S.STORE      KATHIRAVAN K
# 36              VAIKKKAM  STORE        VELLAMUTHU
# 37              VAIKKKAM  STORE        VELLAMUTHU
# 38                  r.d.s store            KATHIR
# 39            SRI LAXMI TRADERS        VELLAMUTHU
# 40            SRI LAXMI TRADERS        VELLAMUTHU
# 41             SRI VISHVA  SHOP      VIJAYABASKAR
# 42               Sarangan Store             VIJAY
# 43               Sarangan Store             VIJAY
# 44                GANESHA STORE     KARTHIKEYAN S
# 45  A.KANTHASAAMY NADAR MALIGAI       RAVIKUMAR M
# 46                 A.R.MALIGAI        RAVIKUMAR M
# 47                 INDIAN STORE  PARMESHWARAN U V
# 48                 INDIAN STORE  PARMESHWARAN U V
# 49             Saraswathi store       KARTHIKEYAN
# 50             Saraswathi store       KARTHIKEYAN
# 51                Kajah maligai       KARTHIKEYAN
# 52                   ASIK STORE       VEERA KUMAR
#
#                          DistName  RtrGroupCde1   RtrGroupCde    InvDate  \
# 0            ARIHANT DISTRIBUTORS  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 1            ARIHANT DISTRIBUTORS  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 2                      PONNI & CO  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 3                      PONNI & CO  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 4                      PONNI & CO  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 5                      PONNI & CO  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 6                 TP DISTRIBUTION  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 7           EVERGREEN ENTERPRISES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 8           EVERGREEN ENTERPRISES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 9           EVERGREEN ENTERPRISES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 10          EVERGREEN ENTERPRISES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 11          EVERGREEN ENTERPRISES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 12                   T.L AGENCIES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 13              MEENATCHI TRADERS  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 14              MEENATCHI TRADERS  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 15              MEENATCHI TRADERS  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 16              MEENATCHI TRADERS  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 17              MEENATCHI TRADERS  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 18              MEENATCHI TRADERS  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 19             STANDARD MARKETING  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 20               VIGNESH AGENCIES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 21               VIGNESH AGENCIES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 22  SRI UKKRAKALIAMMAN MARKETTING  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 23  SRI UKKRAKALIAMMAN MARKETTING  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 24                   S.P.AGENCIES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 25                   S.P.AGENCIES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 26                   S.P.AGENCIES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 27                   S.P.AGENCIES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 28                   S.P.AGENCIES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 29                   S.P.AGENCIES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 30                   S.P.AGENCIES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 31          SRI PONNIAMMAN AGENCY  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 32          SRI PONNIAMMAN AGENCY  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 33               VIGNESH AGENCIES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 34               VIGNESH AGENCIES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 35     SIVAMURUGA TRADING COMPANY  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 36              BHARATHI AGENCIES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 37              BHARATHI AGENCIES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 38                ESWARI AGENCIES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 39               K.PRIYA AGENCIES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 40               K.PRIYA AGENCIES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 41           SAI SRI SARAN AGENCY  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 42                MADURA AGENCIES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 43                MADURA AGENCIES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 44                S.S.S.MARKETING  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 45                 STAR MARKETING  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 46                 STAR MARKETING  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 47          SRI VINAYAGA AGENCIES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 48          SRI VINAYAGA AGENCIES  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 49       RAJALAKSHMI DISTRIBUTORS  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 50       RAJALAKSHMI DISTRIBUTORS  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 51       RAJALAKSHMI DISTRIBUTORS  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
# 52                    VMR TRADERS  PC-WHOLESALE  PC-WHOLESALE 2020-10-26
#
#     PolypouchCount
# 0                9
# 1                9
# 2                9
# 3                9
# 4                9
# 5                9
# 6                9
# 7               45
# 8                9
# 9                9
# 10               1
# 11             180
# 12               8
# 13               1
# 14              18
# 15               9
# 16               9
# 17              18
# 18              18
# 19               1
# 20               1
# 21              18
# 22              27
# 23              27
# 24               2
# 25               9
# 26               9
# 27               9
# 28               9
# 29               9
# 30               9
# 31              27
# 32              27
# 33              18
# 34              18
# 35               9
# 36               9
# 37               9
# 38               1
# 39              16
# 40              16
# 41               9
# 42              90
# 43              90
# 44               3
# 45              27
# 46               9
# 47               9
# 48               9
# 49               1
# 50               1
# 51               1
# 52               2

# %% [markdown]
# ## Other functions

# %%
# Numpy & Pandas for calcs & dataframe
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', None)

# Random pick
import random

# Azure data & credentials
from ckpackages import azsql

# Move files to folder
import shutil
import os,time
import datetime
import datetime as dt

# Merge csv into one
from glob import glob

# IPY - VOILA 
import ipywidgets as widgets
from IPython.display import display, clear_output
from ipywidgets import widgets,Button, Output, VBox,interactive,interact,IntProgress
import time

# %% [markdown]
# ### Move last day from Results to History

# %%
## Move last day results to history
path = os.getcwd()

now = dt.datetime.now()
ago = now-dt.timedelta(hours=24)
strftime = "%H:%M %m/%d/%Y"
created = os.path.join(path + '\Results_csv')
dest = os.path.join(path + '\History_csv')

# Detect files from one folder created or modified in the past 24 hours
for root, dirs,files in os.walk(created):  
    for fname in files:
        path = os.path.join(root, fname)
        st = os.stat(path)    
        mtime = dt.datetime.fromtimestamp(st.st_mtime)
        if mtime > ago:
            print("True:  ", fname, " at ", mtime.strftime("%H:%M %m/%d/%Y"))
            shutil.move(path, dest)
            # this is actual move

# %% [markdown]
# ### Read & join csv in History

# %%
## Read & join csv in same folder
a = os.getcwd()
path = a + '\\History_csv'
all_files = glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)
df_concat = pd.concat(li, axis=0, ignore_index=True)

# Convert InvDate to Date format
df_concat['InvDate'] = pd.to_datetime(df_concat['InvDate'])

## Filter data by instances occuring in last week
days=7 #Last 6 days from current date
cutoff_date = df_concat['InvDate'].max() - pd.Timedelta(days=days)
max_date = df_concat['InvDate'].max()
#print(cutoff_date)

df1_concat = df_concat[(df_concat['InvDate'] >= cutoff_date)]
df1_concat = df_concat[(df_concat['InvDate'] < max_date)]

# List of last 6 days unique retailers
rtr_last6days = df1_concat[['RtrCode','RtrName']].drop_duplicates()
rtrlist_last6days = rtr_last6days['RtrCode'].tolist()
rtrnames_last6days = rtr_last6days['RtrName'].tolist()

# Filter retailer occuring in last 6 days (to be included below)
#data_filtered = data[~data.RtrCode.isin(rtr_last6days)]

# %% [markdown]
# ### Main logic with Voila for Web app

# %%
## Import data
Query = 'select * from v_PC_MeeraRetailerCampaign' 
data = azsql.callstatement(Query)

# Add weekday & current weekday
data['weekday'] = data['InvDate'].dt.dayofweek
currentWeekDay = dt.datetime.now().weekday()

# Data only for Latest date
# On monday, get Sat & Sun data, for other days, get previous day data
if currentWeekDay==0:
    cutoff_date = data['InvDate'].max() - pd.Timedelta(days=1)
    max_date = data['InvDate'].max()
    
    data = data[(data['InvDate'] >= cutoff_date)]
    data = data[(data['InvDate'] <= max_date)]
else:
    data = data[data['InvDate'] == data['InvDate'].max()]

## Remove null - Retailers without AM
# Consider Data with AMName ( remove nulls)
data = data[data['AMName'].notnull()]

# Categories retail group as Wholesale & Retail
data['RtrGroupCde1'] = data['RtrGroupCde'].apply(lambda x: 'PC-WHOLESALE' if x=='PC-WHOLESALE' else 'PC-RETAIL')

# Filter retailer occuring in last 6 days
data = data[~data.RtrCode.isin(rtr_last6days)]

InvDate =  data['InvDate'].iloc[0]
InvDate = str(InvDate)[0:10]

maxdate= str(data['InvDate'].max())[0:10]
print('\nDate: ',maxdate)

TotalRtrCount = data['RtrCode'].count()
print('Unique retailers:', TotalRtrCount)

## Retailer master
rtr_master = data[['RtrCode','RtrName','SMSysName','DistName','RtrGroupCde1','RtrGroupCde','InvDate','PolypouchCount']].drop_duplicates()
rtr_master['PolypouchCount'] = rtr_master['PolypouchCount'].astype(int)

AM_RTR_in = data.groupby(['AMName','RtrGroupCde1'])['RtrCode'].count().reset_index()

# Create text widget for output
output_slider_variable = widgets.Text()

# %%
# Define function to bind value of the input to the output variable 
def f(Lots):
    output_slider_variable.value = str(Lots)

print('\nChoose number of Lots')
# Create input slider with default value = 10  
interact(f, Lots=(10, 100, 1))

def picks(output_slider_variable,data):
    # Create and output new int variable with value of slider
    new_variable = int(output_slider_variable.value)

    ## Choose number of retailers to choose
    ## Weightage for AM
    # Percentage of Retailers across AM-Wise        
    TotalRtrCount = data['RtrCode'].count()
    AM_RTR_WGT = data.groupby(['AMName','RtrGroupCde1'])['RtrCode'].count().reset_index()
    AM_RTR_WGT['LotsPerAM'] = np.ceil((AM_RTR_WGT['RtrCode']/TotalRtrCount) * new_variable)


    ## Split dataframe on AM's
    # Select required rows
    data1 = data[['ZM','AMName','RtrGroupCde1','RtrCode','RtrName','TotalQty','PolypouchCount']]
    data2 = [rows for _, rows in data1.groupby(['AMName','RtrGroupCde1'])]
    return data2,AM_RTR_WGT,new_variable
    
## Function to generate random Rtr's with AM weightage
def randomRtrAmWise(i):
    data3,AM_RTR_WGT,lots = picks(output_slider_variable,data)
    # Retailer name
    a = data3[i]['RtrCode'].tolist()

    # Polypouch count as weight
    ppc = data3[i]['PolypouchCount'].tolist() 

    c=int(AM_RTR_WGT['LotsPerAM'][i])
    #random.shuffle(a)
    l = random.choices(a, weights=ppc, k=c)
    l.sort()
    df_R = pd.DataFrame(l,columns = ['RtrCode'])
    df_R['AMName'] = AM_RTR_WGT['AMName'][i]
    return df_R,AM_RTR_WGT,lots
    
def randompick(rtr_master,AM_RTR_in):
    df_RtrRP = pd.DataFrame()
    for j in range(len( AM_RTR_in.index.tolist())):
        df,AM_RTR_WGT,lots = randomRtrAmWise(j)
        df_RtrRP = df_RtrRP.append(df)

    df_RtrRP = df_RtrRP.merge(rtr_master,on='RtrCode')
    df_RtrRP = df_RtrRP.groupby('RtrCode').head(2).reset_index(drop=True) # Keep 1st two instances of duplicates

    index = df_RtrRP.reset_index().index
    number_of_rows = len(index)
    return df_RtrRP,lots,number_of_rows,AM_RTR_WGT

def randompickAM(rtr_master,AM_RTR_in):
    result,lots,number_of_rows,AM_RTR_WGT = randompick(rtr_master,AM_RTR_in)
    while (number_of_rows!=lots):
        if (number_of_rows==lots):
            display(result)
            print('Ok')
        else:
            result,lots,number_of_rows,AM_RTR_WGT = randompickAM(rtr_master,AM_RTR_in)
            break
    return result,lots,number_of_rows,AM_RTR_WGT

# %%
print('\n')
# Button pick
button = Button(description='Pick')

out = Output()


def on_click(_):
    with out:
        clear_output(True)
        dr,lots,number_of_rows,AM_RTR_WGT = randompickAM(rtr_master,AM_RTR_in)
        
        max_count = 100

        f = IntProgress(min=0, max=max_count) # instantiate the bar
        display(f) # display the bar

        count = 0
        while count <= max_count:
            f.value += 1 # signal to increment the progress bar
            time.sleep(.1)
            count += 1
                
        print('Count of lots: ',lots)
        print('Count of picked retailers: ',number_of_rows)
        print('\n Split of Retailers chosen acorss AMs')
        display(AM_RTR_WGT)
        
        print('\nThe selected retailers on date', InvDate)
        display(dr)
        
        # Save results
        root = 'Results_csv' 
        sheet = 'results_' + InvDate + '.csv' 
        file_name = os.path.join(root,sheet)
        print(file_name)
        dr.to_csv(file_name,index=False)

button.on_click(on_click)

VBox([button])

# %%
VBox([out])
